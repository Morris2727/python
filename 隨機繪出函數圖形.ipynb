# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import sympy as sp
from numpy.random import randint

# %%
from sympy.abc import x,a,b,c

# %%
a = randint(6,8)
b = randint(3,5)
c = randint(1,2)

# %%
y = 2*x**a + 3*x**b + x**c + 6

# %%
y
# Out:
# 2*x**7 + 3*x**4 + x + 6

# %%
sp.plot(y)

# %%
g = sp.diff(y)

# %%
g
# Out:
# 14*x**6 + 12*x**3 + 1

# %%
sp.plot(g)

# %%
/*
