# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import sympy as sp
from numpy.random import randint

# %%
from sympy.abc import x,a,b,c

# %%
a = randint(6,8)
b = randint(3,5)
c = randint(1,2)

# %%
y = 2*x**a + 3*x**b + x**c + 6

# %%
y
# Out:
# 2*x**6 + 3*x**3 + x + 6

# %%
sp.plot(y)

# %%
g = sp.diff(y)

# %%
g
# Out:
# 12*x**5 + 9*x**2 + 1

# %%
sp.plot(g)

# %%
/*
